# %%
import cv2
import numpy as np
from skimage import io
from matplotlib import pyplot as plt

def url_to_image(url):
    print("downloading %s" % (url))
    return cv2.cvtColor(io.imread(url), cv2.COLOR_BGR2RGB)

url = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/images/bookpage1.jpg"
img = url_to_image(url)
grayscaled = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/images/bookpage1.jpg

# %%
def cv2_imshow(img, cmap=None):
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10, 15))
    
    if cmap:
        plt.imshow(img)
    else:
        plt.imshow(img, cmap=cmap)

# %% [markdown]
# Box filter

# %%
kernel = np.ones((7,7),np.float32)/49
im1 = cv2.filter2D(img,-1,kernel)
cv2_imshow(im1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-4f19591cb18a> in <module>
#       1 kernel = np.ones((7,7),np.float32)/49
#       2 im1 = cv2.filter2D(img,-1,kernel)
# ----> 3 cv2_imshow(im1)
#
# TypeError: cv2_imshow() missing 1 required positional argument: 'cmap'

# %% [markdown]
# Gaussian Blur

# %%
im2 = cv2.GaussianBlur(img,(7,7),0)
cv2_imshow(im2)

# %% [markdown]
# Білатеральний фільтр

# %%
im3 = cv2.bilateralFilter(img,9,75,75)
cv2_imshow(im3)

# %% [markdown]
# Поріг

# %%
retval, threshold = cv2.threshold(grayscaled, 24, 255, cv2.THRESH_BINARY)
cv2_imshow(threshold)

# %% [markdown]
# Інверсія

# %%
t_inv = (255-threshold)
cv2_imshow(t_inv)

# %% [markdown]
# Ерозія і дилатація

# %%
kernel = np.ones((3,3), np.uint8) 
img_erosion = cv2.erode(threshold, kernel, iterations=1) 
img_dilation = cv2.dilate(t_inv, kernel, iterations=1) 
cv2_imshow(img_erosion)
cv2_imshow(img_dilation)

# %%
url = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/text/text1.jpg"
img = url_to_image(url)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/text/text1.jpg

# %%
# 
plt.figure(figsize=(15, 10))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2_imshow(img)
